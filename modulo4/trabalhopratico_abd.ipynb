# %% [markdown]
# https://openflights.org/data.html
#
#
# 1. Airport ID	Unique OpenFlights identifier for this airport.
# 2. Name	Name of airport. May or may not contain the City name.
# 3. City	Main city served by airport. May be spelled differently from Name.
# 4. Country	Country or territory where airport is located. See Countries to cross-reference to ISO 3166-1 codes.
# 5. IATA	3-letter IATA code. Null if not assigned/unknown.
#  ICAO	4-letter ICAO code. Null if not assigned.
# 6. Latitude	Decimal degrees, usually to six significant digits. Negative is South, positive is North.
# 7. Longitude	Decimal degrees, usually to six significant digits. Negative is West, positive is East.
# 8. Altitude	In feet.
# 9. Timezone	Hours offset from UTC. Fractional hours are expressed as decimals, eg. India is 5.5.
# 10. DST	Daylight savings time. One of E (Europe), A (US/Canada), S (South America), O (Australia), Z (New Zealand), N (None) or U (Unknown). See also: Help: Time
# 11. Tz database time zone	Timezone in "tz" (Olson) format, eg. "America/Los_Angeles".
# Type	Type of the airport. Value "airport" for air terminals, "station" for train stations, "port" for ferry terminals and "unknown" if not known. In airports.csv, only type=airport is included.
# 12. Source	Source of this data. "OurAirports" for data sourced from OurAirports, "Legacy" for old data not matched to OurAirports (mostly DAFIF), "User" for unverified user contributions. In airports.csv, only source=OurAirports is included.

# %%
#Os conjuntos de dados InvestmentBankCDE
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat", sep=",", header=None)

# %%
df
# Out:
#          0                                            1             2   \
# 0         1                               Goroka Airport        Goroka
# 1         2                               Madang Airport        Madang
# 2         3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3         4                               Nadzab Airport        Nadzab
# 4         5  Port Moresby Jacksons International Airport  Port Moresby
# ...     ...                                          ...           ...
# 7693  14106                          Rogachyovo Air Base        Belaya
# 7694  14107                        Ulan-Ude East Airport      Ulan Ude
# 7695  14108                         Krechevitsy Air Base      Novgorod
# 7696  14109                  Desierto de Atacama Airport       Copiapo
# 7697  14110                           Melitopol Air Base     Melitopol
#
#                     3    4     5          6           7     8   9   10  \
# ...

# %%
df.sort_values(9)
# Out:
#          0                         1                        2           3   \
# 1590   1633     João Paulo II Airport            Ponta Delgada    Portugal
# 4369   5675        São Filipe Airport  Sao Filipe, Fogo Island  Cape Verde
# 7488  13412  Semur En Auxois Airfield          Semur en Auxois      France
# 1591   1634              Pico Airport                     Pico    Portugal
# 4482   5793             Corvo Airport                    Corvo    Portugal
# ...     ...                       ...                      ...         ...
# 7277  12040             Tumut Airport                      NaN   Australia
# 7278  12041        Wangaratta Airport                      NaN   Australia
# 7279  12042     Warracknabeal Airport                      NaN   Australia
# 7281  12044         West Sale Airport                     Sale   Australia
# 7697  14110        Melitopol Air Base                Melitopol     Ukraine
#
# ...

# %%
df.loc[(df[3]== 'Brazil')&(df[2].str.match( '.*PAULO',case=False))]
# Out:
#         0                                                  1   \
# 2436  2564  Guarulhos - Governador André Franco Montoro In...
# 2464  2593                             Campo de Marte Airport
# 2486  2618                                  Congonhas Airport
# 2499  2631                               Paulo Afonso Airport
# 6046  8256                   Senadora Eunice Micheles Airport
# 6397  8927                                    Lorenzo Airport
#
#                          2       3    4     5          6          7     8   \
# 2436              Sao Paulo  Brazil  GRU  SBGR -23.435556 -46.473057  2459
# 2464              Sao Paulo  Brazil   \N  SBMT -23.509100 -46.637798  2368
# 2486              Sao Paulo  Brazil  CGH  SBSP -23.626110 -46.656387  2631
# 2499          Paulo Alfonso  Brazil  PAV  SBUF  -9.400880 -38.250599   883
# 6046  Sao Paulo de Olivenca  Brazil  OLC  SDCG  -3.467930 -68.920412   335
# 6397     Morro de Sao Paulo  Brazil   \N  SNCL -13.389444 -38.910000     3
#
# ...

# %%
df.loc[(df[3]== 'Brazil')]
# Out:
#          0                                     1                      2   \
# 2392   2518         Conceição do Araguaia Airport  Conceicao Do Araguaia
# 2393   2519  Campo Délio Jardim de Mattos Airport         Rio De Janeiro
# 2394   2520                         Amapá Airport                  Amapa
# 2395   2521                    Araraquara Airport             Araracuara
# 2396   2522                   Santa Maria Airport                Aracaju
# ...     ...                                   ...                    ...
# 7643  13723                Augusto Severo Airport                  Natal
# 7647  13735                        Flores Airport                 MANAUS
# 7659  13772               Fazenda Uiapuru Airport               COMODORO
# 7670  13830              Fazenda Kajussol Airport  Alta Floresta D'Oeste
# 7672  13881                 Costa Marques Airport          COSTA MARQUES
#
#           3    4     5          6          7     8   9   10  \
# ...

# %%
#maior numero de aeroportos por cidade
df.groupby(2)[2].count().sort_values(ascending=False)
# Out:
# 2
# London        9
# Columbus      8
# San Jose      7
# Georgetown    7
# Alexandria    6
#              ..
# Helgoland     1
# Helena        1
# Heihe         1
# Heho          1
# Žilina        1
# Name: 2, Length: 6955, dtype: int64

# %%
#maior numero de aeroporto por pais
df.groupby(3)[3].count().sort_values(ascending=False)
# Out:
# 3
# United States              1512
# Canada                      430
# Australia                   334
# Russia                      264
# Brazil                      264
#                            ...
# Cocos (Keeling) Islands       1
# Christmas Island              1
# Niue                          1
# Norfolk Island                1
# Grenada                       1
# Name: 3, Length: 237, dtype: int64

# %%
df.describe()
# Out:
#                   0            6            7             8
# count   7698.000000  7698.000000  7698.000000   7698.000000
# mean    5170.950117    25.808442    -1.390546   1015.873344
# std     3777.259930    28.404946    86.519162   1628.775132
# min        1.000000   -90.000000  -179.876999  -1266.000000
# 25%     1993.250000     6.907983   -78.974699     63.000000
# 50%     4068.000000    34.085701     6.375653    352.000000
# 75%     7728.750000    47.239551    56.000599   1203.000000
# max    14110.000000    89.500000   179.951004  14472.000000

# %%
#Considerando o dataset airports.dat, qual aeroporto apresenta a maior altitude? 14472 ft, Daocheng Yading Airport	Daocheng
df.sort_values(8,ascending=False)
# Out:
#         0                                    1             2              3   \
# 6542  9310              Daocheng Yading Airport      Daocheng          China
# 5028  6396                 Qamdo Bangda Airport        Bangda          China
# 6393  8921                     Kangding Airport      Kangding          China
# 5872  7932                  Ngari Gunsa Airport     Shiquanhe          China
# 2625  2762        El Alto International Airport        La Paz        Bolivia
# ...    ...                                  ...           ...            ...
# 2069  2151                       Ramsar Airport        Ramsar           Iran
# 4087  4357                       Atyrau Airport        Atyrau     Kazakhstan
# 5721  7646  Jacqueline Cochran Regional Airport  Palm Springs  United States
# 1553  1595                   Ein Yahav Airfield     Eyn-yahav         Israel
# 1558  1600                  Bar Yehuda Airfield       Metzada         Israel
#
# ...

# %%
#Considerando o dataset airports.dat, qual é a média de aeroportos por país?
df.groupby(3)[3].count().mean()
# Out:
# 32.48101265822785

# %%
#Considerando o dataset airports.dat, qual é a média de altitude dos aeroportos?
df[8].mean()
# Out:
# 1015.873343725643

# %%
df[(df[1]== 'Madang Airport')|(df[0]==2564)|(df[1]=='Goroka Airport') ]
# Out:
#         0                                                  1          2   \
# 0        1                                     Goroka Airport     Goroka
# 1        2                                     Madang Airport     Madang
# 2436  2564  Guarulhos - Governador André Franco Montoro In...  Sao Paulo
#
#                     3    4     5          6           7     8   9  10  \
# 0     Papua New Guinea  GKA  AYGA  -6.081690  145.391998  5282  10  U
# 1     Papua New Guinea  MAG  AYMD  -5.207080  145.789001    20  10  U
# 2436            Brazil  GRU  SBGR -23.435556  -46.473057  2459  -3  S
#
#                         11       12           13
# 0     Pacific/Port_Moresby  airport  OurAirports
# 1     Pacific/Port_Moresby  airport  OurAirports
# 2436     America/Sao_Paulo  airport  OurAirports
